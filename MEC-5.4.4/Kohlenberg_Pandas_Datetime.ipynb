# %%
conda install pandas-datareader
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/bradkohl/opt/anaconda3/envs/mec-miniprojects
#
#   added / updated specs:
#     - pandas-datareader
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          45 KB
#     bottleneck-1.3.4           |   py37h67323c0_0         116 KB
#     brotlipy-0.7.0             |py37h9ed2024_1003         333 KB
#     cryptography-37.0.1        |   py37hf6deb26_0         1.1 MB
#     idna-3.3                   |     pyhd3eb1b0_0          49 KB
#     libxml2-2.9.14             |       hbf8cd5e_0         641 KB
#     libxslt-1.1.35             |       h5b33f42_0         420 KB
#     lxml-4.8.0                 |   py37h65b224f_0         1.1 MB
#     numexpr-2.8.1              |   py37h9c3cb84_0         121 KB
#     pandas-1.3.5               |   py37h743cdd8_0         8.9 MB
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          50 KB
#     pysocks-1.7.1              |   py37hecd8cb5_0          31 KB
#     pytz-2022.1                |   py37hecd8cb5_0         196 KB
#     requests-2.27.1            |     pyhd3eb1b0_0          54 KB
#     urllib3-1.26.9             |   py37hecd8cb5_0         182 KB
#     ------------------------------------------------------------
#                                            Total:        13.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-64::blas-1.0-openblas
#   bottleneck         pkgs/main/osx-64::bottleneck-1.3.4-py37h67323c0_0
#   brotlipy           pkgs/main/osx-64::brotlipy-0.7.0-py37h9ed2024_1003
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   cryptography       pkgs/main/osx-64::cryptography-37.0.1-py37hf6deb26_0
#   icu                pkgs/main/osx-64::icu-58.2-h0a44026_3
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0_0
#   libxml2            pkgs/main/osx-64::libxml2-2.9.14-hbf8cd5e_0
#   libxslt            pkgs/main/osx-64::libxslt-1.1.35-h5b33f42_0
#   lxml               pkgs/main/osx-64::lxml-4.8.0-py37h65b224f_0
#   numexpr            pkgs/main/osx-64::numexpr-2.8.1-py37h9c3cb84_0
#   pandas             pkgs/main/osx-64::pandas-1.3.5-py37h743cdd8_0
#   pandas-datareader  pkgs/main/noarch::pandas-datareader-0.10.0-pyhd3eb1b0_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-22.0.0-pyhd3eb1b0_0
#   pysocks            pkgs/main/osx-64::pysocks-1.7.1-py37hecd8cb5_0
#   pytz               pkgs/main/osx-64::pytz-2022.1-py37hecd8cb5_0
#   requests           pkgs/main/noarch::requests-2.27.1-pyhd3eb1b0_0
#   urllib3            pkgs/main/osx-64::urllib3-1.26.9-py37hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# bottleneck-1.3.4     | 116 KB    | ##################################### | 100%
# lxml-4.8.0           | 1.1 MB    | ##################################### | 100%
# libxml2-2.9.14       | 641 KB    | ##################################### | 100%
# pyopenssl-22.0.0     | 50 KB     | ##################################### | 100%
# cryptography-37.0.1  | 1.1 MB    | ##################################### | 100%
# pytz-2022.1          | 196 KB    | ##################################### | 100%
# requests-2.27.1      | 54 KB     | ##################################### | 100%
# blas-1.0             | 45 KB     | ##################################### | 100%
# pandas-1.3.5         | 8.9 MB    | ##################################### | 100%
# idna-3.3             | 49 KB     | ##################################### | 100%
# urllib3-1.26.9       | 182 KB    | ##################################### | 100%
# libxslt-1.1.35       | 420 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 333 KB    | ##################################### | 100%
# pysocks-1.7.1        | 31 KB     | ##################################### | 100%
# numexpr-2.8.1        | 121 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_datareader import data

goog = data.DataReader('GOOG', start='2004', end='2016',data_source='yahoo')
goog.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2004-08-19  51.835709  47.800831  49.813290  49.982655  44871361.0  49.982655
# 2004-08-20  54.336334  50.062355  50.316402  53.952770  22942874.0  53.952770
# 2004-08-23  56.528118  54.321388  55.168217  54.495735  18342897.0  54.495735
# 2004-08-24  55.591629  51.591621  55.412300  52.239197  15319808.0  52.239197
# 2004-08-25  53.798351  51.746044  52.284027  52.802086   9232276.0  52.802086

# %%
goog = goog['Close']

# %%
goog
# Out:
# Date
# 2004-08-19     49.982655
# 2004-08-20     53.952770
# 2004-08-23     54.495735
# 2004-08-24     52.239197
# 2004-08-25     52.802086
#                  ...
# 2015-12-24    748.400024
# 2015-12-28    762.510010
# 2015-12-29    776.599976
# 2015-12-30    771.000000
# 2015-12-31    758.880005
# Name: Close, Length: 2863, dtype: float64
